# %%
# !pip list | grep seaborn

# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %% [markdown]
# question 2 :

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-219dd280-1795-4a60-9b92-e16fd7fc99f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-219dd280-1795-4a60-9b92-e16fd7fc99f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pokemon = pd.read_csv('house_pricing.csv') 
ar = pd.DataFrame(pokemon)
ar.dtypes
tips = sb.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# question 3:

# %%
sb.set_theme()
sb.relplot(
    data=ar,
    x="LotArea", y="SalePrice", 
)

# %% [markdown]
# question 4 :

# %%
ar2 = ar[(ar["LotArea"]<20000)&(ar["SalePrice"]<500000)]
sb.relplot(
    data=ar2,
    x="SalePrice", y="LotArea", 
)

# %% [markdown]
# question 5

# %%
sb.relplot(
    data=ar,
    x="LotFrontage", y="LotArea", 
)

# %% [markdown]
# question 6

# %%
ar3 = ar[(ar["LotArea"]<100000)&(ar["LotFrontage"]<200)]
sb.relplot(
    data=ar3,
    x="LotFrontage", y="LotArea", 
)

# %% [markdown]
# EXO 2 :
# QUestion 1:

# %%
from google.colab import files
uploaded = files.upload()
sales_predictions = pd.read_csv('sales_predictions.csv') 
hp = pd.DataFrame(sales_predictions)
hp.dtypes
# Out:
#      <input type="file" id="files-36af9a40-f198-4877-a9ec-46a5c2f82a9c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-36af9a40-f198-4877-a9ec-46a5c2f82a9c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Question 2 :

# %%
sb.relplot(
    data=hp,
    x="date", y="item_price", 
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-cf09721fe8d2> in <module>
#       1 sb.relplot(
# ----> 2     data=hp,
#       3     x="date", y="item_price",
#       4 )
#
# NameError: name 'hp' is not defined

# %% [markdown]
# On peut voir que les point sont superposé et rend l'interprétation dificile
#
# question 3 :

# %%
sb.relplot(
    data=hp.sample(n=50),
    x="date", y="item_price", 
)
hp

# %% [markdown]
# question 5 et 6:

# %%
hp["date"]=pd.to_datetime(hp['date'],format='%d.%m.%Y')
sb.relplot(
    data=hp.sample(n=50),
    x="date", y="item_price", 
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-54c31ac704f7> in <module>
# ----> 1 hp["date"]=pd.to_datetime(hp['date'],format='%d.%m.%Y')
#       2 sb.relplot(
#       3     data=hp.sample(n=50),
#       4     x="date", y="item_price",
#       5 )
#
# NameError: name 'hp' is not defined

# %% [markdown]
# exo 3
#
# question 1 :

# %%
from google.colab import files
uploaded = files.upload()
IBM_HR_ATTRITION = pd.read_csv('IBM_HR_ATTRITION.csv') 
ibm = pd.DataFrame(IBM_HR_ATTRITION)
ibm
# Out:
#      <input type="file" id="files-31ff9104-5ce2-4274-a08d-bb6107a69d48" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-31ff9104-5ce2-4274-a08d-bb6107a69d48">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# question 2 :

# %%
ibm2 = ibm[(ibm["Attrition"]==1)]
sb.catplot(
    data=ibm2,
    x="JobSatisfaction", y="EmployeeNumber", 
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-2e57a7b61aaa> in <module>
#       2 sb.catplot(
#       3     data=ibm2,
# ----> 4     x="JobSatisfaction", y="EmployeeNumber",
#       5 )
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3814     # so we need to define ``palette`` to get default behavior for the
# ...

# %% [markdown]
# Question 3:

# %%
sb.boxplot(
    data=ibm,
    x="JobSatisfaction", y="Attrition", 
)

# %% [markdown]
# question 8:

# %%
sb.boxplot(
    data=ibm,
    x="TotalWorkingYears", y="Attrition", 
)

# %%
ibm3 = ibm[(ibm["TotalWorkingYears"]<20)]
sb.boxplot(
    data=ibm3,
    x="TotalWorkingYears", y="Attrition", 
)

# %%
ibm["TotalWorkingYears"].describe()
# Out:
# count    1470.000000
# mean       11.279592
# std         7.780782
# min         0.000000
# 25%         6.000000
# 50%        10.000000
# 75%        15.000000
# max        40.000000
# Name: TotalWorkingYears, dtype: float64

# %% [markdown]
# question 9:

# %%
ibm['Attrition'] = ibm['Attrition'].replace("No",0)
ibm['Attrition']= ibm['Attrition'].replace("Yes",1)
ibm
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# question 10:

# %%
sb.catplot(
    data=ibm,
    x="EducationField", y="Attrition", kind="bar", height=10 
)

# %% [markdown]
# exercice 4 :

# %%
sb.displot(
    data=ibm,
     x="MonthlyIncome", 
)

# %% [markdown]
# question 3

# %%
ib = ibm[(ibm["MonthlyIncome"]<5000)]
sb.displot(
    data=ib,
    x="MonthlyIncome", 
)

# %% [markdown]
# Exercice 5 :
#
# question 2 :

# %%
sb.lmplot(
    data=ibm,
    x="DistanceFromHome", y="Attrition", 
)

# %% [markdown]
# question 3:

# %%
sb.lmplot(
    data=ibm,
    x="YearsWithCurrManager", y="Attrition", 
)

# %% [markdown]
# Exercice 6:
#
# question 2 :

# %%
hp = pd.read_csv('house_pricing.csv') 
hp = pd.DataFrame(hp)
last_column = hp.iloc[: , -15:]
last_column
# Out:
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0           61              0          0            0
# 1            298            0              0          0            0
# 2              0           42              0          0            0
# 3              0           35            272          0            0
# 4            192           84              0          0            0
# ...          ...          ...            ...        ...          ...
# 1455           0           40              0          0            0
# 1456         349            0              0          0            0
# 1457           0           60              0          0            0
# 1458         366            0            112          0            0
# 1459         736           68              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# ...

# %% [markdown]
# question 3:

# %%
coorel = last_column.corr()
coorel
# Out:
#                WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# WoodDeckSF       1.000000     0.058661      -0.125989  -0.032771    -0.074181
# OpenPorchSF      0.058661     1.000000      -0.093079  -0.005842     0.074304
# EnclosedPorch   -0.125989    -0.093079       1.000000  -0.037305    -0.082864
# 3SsnPorch       -0.032771    -0.005842      -0.037305   1.000000    -0.031436
# ScreenPorch     -0.074181     0.074304      -0.082864  -0.031436     1.000000
# PoolArea         0.073378     0.060762       0.054203  -0.007992     0.051307
# MiscVal         -0.009551    -0.018584       0.018361   0.000354     0.031946
# MoSold           0.021011     0.071255      -0.028887   0.029474     0.023217
# YrSold           0.022270    -0.057619      -0.009916   0.018645     0.010694
# SalePrice        0.324413     0.315856      -0.128578   0.044584     0.111447
#
#                PoolArea   MiscVal    MoSold    YrSold  SalePrice
# ...

# %% [markdown]
# question 4 :

# %%
sb.heatmap(
    data=coorel,
)

# %% [markdown]
# exercice 7:
#
# question 2:

# %%
from google.colab import files
uploaded = files.upload()
resto = pd.read_csv('resto.csv') 
resto = pd.DataFrame(hp)
# Out:
#      <input type="file" id="files-1377bf47-f10b-499c-89f6-f7ae70dfc7b8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1377bf47-f10b-499c-89f6-f7ae70dfc7b8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
resto.iloc[:10 , :]
# Out:
#    Unnamed: 0  order_id  quantity                              item_name  \
# 0           0         1         1           Chips and Fresh Tomato Salsa
# 1           1         1         1                                   Izze
# 2           2         1         1                       Nantucket Nectar
# 3           3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4           4         2         2                           Chicken Bowl
# 5           5         3         1                           Chicken Bowl
# 6           6         3         1                          Side of Chips
# 7           7         4         1                          Steak Burrito
# 8           8         4         1                       Steak Soft Tacos
# 9           9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# ...

# %%
resto.iloc[:0 , :]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, order_id, quantity, item_name, choice_description, item_price]
# Index: []

# %%
resto1 = resto.groupby(['item_name']).sum()
resto1.sort_values("quantity",ascending=False)
# Out:
#                                        Unnamed: 0  order_id  quantity
# item_name
# Chicken Bowl                              1779909    713926       761
# Chicken Burrito                           1238217    497303       591
# Chips and Guacamole                       1121773    449959       506
# Steak Burrito                              817795    328437       386
# Canned Soft Drink                          759990    304753       351
# Chips                                      518704    208004       230
# Steak Bowl                                 482721    193752       221
# Bottled Water                              439354    175944       211
# Chips and Fresh Tomato Salsa               250144    100419       130
# Canned Soda                                189915     76396       126
# Chicken Salad Bowl                         292292    117104       123
# Chicken Soft Tacos                         244891     98395       120
# ...

# %% [markdown]
# question 7:

# %%
resto3 = resto["item_price"].str.replace("$","")
resto4 = pd.to_numeric(resto3)
resto4.sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# 34500.16

# %% [markdown]
# question 8:

# %%
resto1["quantity"].sum()
# Out:
# 4972

# %% [markdown]
# question 9 :

# %%
resto4.mean()
# Out:
# 7.464335785374297

# %%
from google.colab import files
uploaded = files.upload()
cancer = pd.read_csv('30-70cancerChdEtc.csv') 
cancer = pd.DataFrame(cancer)
# Out:
#      <input type="file" id="files-f31a46f9-8fe9-49b0-bf33-48bd83eab857" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f31a46f9-8fe9-49b0-bf33-48bd83eab857">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
cancer
# Out:
#          Location  Period                                          Indicator  \
# 0     Afghanistan    2016  Probability (%) of dying between age 30 and ex...
# 1     Afghanistan    2016  Probability (%) of dying between age 30 and ex...
# 2     Afghanistan    2016  Probability (%) of dying between age 30 and ex...
# 3     Afghanistan    2015  Probability (%) of dying between age 30 and ex...
# 4     Afghanistan    2015  Probability (%) of dying between age 30 and ex...
# ...           ...     ...                                                ...
# 2740     Zimbabwe    2005  Probability (%) of dying between age 30 and ex...
# 2741     Zimbabwe    2005  Probability (%) of dying between age 30 and ex...
# 2742     Zimbabwe    2000  Probability (%) of dying between age 30 and ex...
# 2743     Zimbabwe    2000  Probability (%) of dying between age 30 and ex...
# 2744     Zimbabwe    2000  Probability (%) of dying between age 30 and ex...
#
#             Dim1  First Tooltip
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-37cb2243-74ee-4892-aaab-5127e5ca2827" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-37cb2243-74ee-4892-aaab-5127e5ca2827">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
co2 = pd.read_csv('co2.csv') 
co2 = pd.DataFrame(co2)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-30-9f071ec4ab1e> in <module>
# ----> 1 co2 = pd.read_csv('co2.csv')
#       2 co2 = pd.DataFrame(co2)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
